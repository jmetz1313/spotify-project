# %%
import pandas as pd

df = pd.read_csv('week_2_dataset.csv')

# %%
# look at structure of the data
df
# Out:
#                                 Song               Artist  Popularity  BPM  \
# 0                      Smalltown Boy         Bronski Beat           3  135
# 1                 I'm Still Standing           Elton John           6  177
# 2                         Funky Town           Lipps Inc.           6  122
# 3                     I'm So Excited  The Pointer Sisters          65   92
# 4                   Cheri Cheri Lady       Modern Talking          82  114
# ...                              ...                  ...         ...  ...
# 4484  Rock with You - Single Version      Michael Jackson          82  114
# 4485                  You Sexy Thing        Hot Chocolate          75  106
# 4486                       Get It On               T. Rex          72  127
# 4487   Love Really Hurts Without You          Billy Ocean           1  141
# 4488           I Can See Clearly Now          Johnny Nash          51  124
#
#        Time  Dance  Energy  Acoustic  Instrumental  Happy  Speech  Live  \
# 0     05:03     68      56        53             7     93       0    20
# 1     03:01     49      93        46             0     79      10    30
# 2     03:59     91      63         0            62     34       0    10
# 3     03:49     69      86        10             0     69       0    10
# 4     03:46     68      62        46             1     85       0    30
# ...     ...    ...     ...       ...           ...    ...     ...   ...
# 4484  03:40     81      54        18             0     85       0    10
# 4485  04:04     79      73        52             0     96       0    10
# 4486  04:22     73      88        18            86     91       0    60
# 4487  02:58     52      91         0             0     96       0    10
# 4488  02:42     68      53        41             0     58       0     0
#
#       Loud (Db)          Key Camelot         Artist_Clean  \
# 0           -11        A#/B♭      6B         Bronski Beat
# 1            -6  A#/B♭ minor      3A           Elton John
# 2            -8            C      8B           Lipps Inc.
# 3            -6        G#/A♭      4B  The Pointer Sisters
# 4           -14        A#/B♭      6B       Modern Talking
# ...         ...          ...     ...                  ...
# 4484        -13        C♯/D♭      3B      Michael Jackson
# 4485         -5            F      7B        Hot Chocolate
# 4486         -7      B minor     10A               T. Rex
# 4487         -4            F      7B          Billy Ocean
# 4488         -9            D     10B          Johnny Nash
#
#                          Song_Clean                                Genre Tags  \
# 0                     Smalltown Boy   80s, new wave, synthpop, pop, synth pop
# 1                I'm Still Standing  pop, 80s, elton john, rock, classic rock
# 2                        Funky Town               Disco, 80s, pop, 70s, dance
# 3                    I'm So Excited              80s, Disco, pop, dance, soul
# 4                  Cheri Cheri Lady    80s, Disco, pop, Modern Talking, dance
# ...                             ...                                       ...
# 4484                  Rock with You   pop, michael jackson, 80s, Disco, dance
# 4485                 You Sexy Thing               Disco, 70s, funk, soul, pop
# 4486                      Get It On  glam rock, 70s, classic rock, rock, glam
# 4487  Love Really Hurts Without You                80s, pop, soul, 70s, Disco
# 4488          I Can See Clearly Now            reggae, 70s, pop, oldies, soul
#
#                                                  lyrics
# 0     To your soul\nTo your soul\nCry\nCry\nCry\n\nY...
# 1     You could never know what it's like\nYour bloo...
# 2     Gotta make a move to a town that's right for m...
# 3     Tonight's the night we're gonna make it happen...
# 4     Oh, I cannot explain\nEvery time, it's the sam...
# ...                                                 ...
# 4484  Girl, close your eyes\nLet that rhythm get int...
# 4485  I believe in miracles\nWhere're you from?\nYou...
# 4486  Well, you're dirty and sweet\nClad in black, d...
# 4487  You run around town like a fool and you think ...
# 4488  I can see clearly now the rain is gone\nI can ...
#
# [4489 rows x 19 columns]

# %%
df.shape  # (rows, columns)
# Out:
# (4489, 19)

# %% [markdown]
# There are 4489 unique songs in the dataset with 19 total columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4489 entries, 0 to 4488
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Song          4489 non-null   object
#  1   Artist        4489 non-null   object
#  2   Popularity    4489 non-null   int64
#  3   BPM           4489 non-null   int64
#  4   Time          4136 non-null   object
#  5   Dance         4489 non-null   int64
#  6   Energy        4489 non-null   int64
#  7   Acoustic      4489 non-null   int64
#  8   Instrumental  4489 non-null   int64
#  9   Happy         4489 non-null   int64
#  10  Speech        4489 non-null   int64
#  11  Live          4489 non-null   int64
#  12  Loud (Db)     4489 non-null   int64
#  13  Key           4489 non-null   object
#  14  Camelot       4489 non-null   object
#  15  Artist_Clean  4489 non-null   object
#  16  Song_Clean    4489 non-null   object
#  17  Genre Tags    4489 non-null   object
#  18  lyrics        4489 non-null   object
# dtypes: int64(10), object(9)
# memory usage: 666.5+ KB

# %% [markdown]
# Should we remove those without time? Will we be using time as a feature? Only feature with nulls currently...

# %%
df.describe(include='object')
# Out:
#           Song        Artist   Time   Key Camelot Artist_Clean Song_Clean  \
# count     4489          4489   4136  4489    4489         4489       4489
# unique    4316          2009    356    24      24         1632       4284
# top     Closer  Taylor Swift  03:32     C      8B        Drake     Heaven
# freq         4            49     46   429     429           66          4
#
#            Genre Tags                                             lyrics
# count            4489                                               4489
# unique           4180                                               4471
# top     Bryson Tiller  One love, one heart\nLet's get together and fe...
# freq               12                                                  2

# %% [markdown]
# Looks like I didn't clean this data well enough the first time. Many songs have the same names, but duplicate lyrics are very concerning. I will clean those out and then further investigate the duplicate songs

# %%
df[df['lyrics'].duplicated(keep=False)] # find duplicates
# Out:
#                                                    Song  \
# 96               Running Up That Hill (A Deal With God)
# 119                                      What A Feeling
# 435                                             On & On
# 771                                   Take Me to Church
# 798                                      Ode To Viceroy
# 946              Snow On The Beach (feat. Lana Del Rey)
# 1037        Snow On The Beach (feat. More Lana Del Rey)
# 1104                        One Love / People Get Ready
# 1233                                  Take Me To Church
# 1246                                   Sultans Of Swing
# 1254  Rocket Man (I Think It's Going To Be A Long, L...
# 1259                            House of the Rising Sun
# 1362                                  Send Me on My Way
# 1428                                   Just Like Heaven
# 1480  Running Up That Hill (A Deal With God) - 2018 ...
# 1585                                   Just like Heaven
# 1589  Rocket Man (I Think It's Going To Be A Long Lo...
# 2002                                     Ode to Viceroy
# 2024                                   Sultans of Swing
# 2073                                  Send Me On My Way
# 2131                        Flashdance...What A Feeling
# 2366                              OMG (feat. will.i.am)
# 2539                                    F**kin' Perfect
# 2765                                                OMG
# 3001                                Fishing In The Dark
# 3003                                Fishin' in the Dark
# 3237                                            On & On
# 3246                           Day 'N' Nite (nightmare)
# 3555                             Runnin' with the Devil
# 3764                        Lola - 2020 Stereo Remaster
# 3846                           Day 'N' Nite (Nightmare)
# 3955                            House Of The Rising Sun
# 3990                             Runnin' With The Devil
# 2131  First, when there's nothing, but a slow glowin...
# 2366  O.M.G = Oh My God!\nMany of us have had that t...
# 2539  Made a wrong turn, once or twice\nDug my way o...
# 2765  O.M.G = Oh My God!\nMany of us have had that t...
# 3001  Lazy yellow moon comin' up tonight\nShinin' th...
# 3003  Lazy yellow moon comin' up tonight\nShinin' th...
# 3237  Hold me close 'til I get up\nTime is barely on...
# 3246  Uh, uh\nUh, uh\nUh, uh\n\nDay and night\nI tos...
# 3555  Yeah, yeah, yeah\nAh, yeah\n\nI live my life l...
# 3764  I met her in a club down in old Soho\nWhere yo...
# 3846  Uh, uh\nUh, uh\nUh, uh\n\nDay and night\nI tos...
# 3955  There is a house in New Orleans\nThey call the...
# 3990  Yeah, yeah, yeah\nAh, yeah\n\nI live my life l...
# 4291  Made a wrong turn, once or twice\nDug my way o...
# 4339  I met her in a club down in old Soho\nWhere yo...
# 4483  One love, one heart\nLet's get together and fe...

# %%
#removing duplicates with lowest popularity
rows_to_remove = [1480, 2131, 435, 771, 798, 946, 1104, 2024, 1589, 3955, 1362, 1585, 2765, 2539, 3001, 3846, 3990, 4339]  # row numbers (zero-based)
df = df.drop(index=df.index[rows_to_remove])
df = df.reset_index(drop=True)

# %%
df
# Out:
#                                 Song               Artist  Popularity  BPM  \
# 0                      Smalltown Boy         Bronski Beat           3  135
# 1                 I'm Still Standing           Elton John           6  177
# 2                         Funky Town           Lipps Inc.           6  122
# 3                     I'm So Excited  The Pointer Sisters          65   92
# 4                   Cheri Cheri Lady       Modern Talking          82  114
# ...                              ...                  ...         ...  ...
# 4466  Rock with You - Single Version      Michael Jackson          82  114
# 4467                  You Sexy Thing        Hot Chocolate          75  106
# 4468                       Get It On               T. Rex          72  127
# 4469   Love Really Hurts Without You          Billy Ocean           1  141
# 4470           I Can See Clearly Now          Johnny Nash          51  124
#
#        Time  Dance  Energy  Acoustic  Instrumental  Happy  Speech  Live  \
# 0     05:03     68      56        53             7     93       0    20
# 1     03:01     49      93        46             0     79      10    30
# 2     03:59     91      63         0            62     34       0    10
# 3     03:49     69      86        10             0     69       0    10
# 4     03:46     68      62        46             1     85       0    30
# ...     ...    ...     ...       ...           ...    ...     ...   ...
# 4466  03:40     81      54        18             0     85       0    10
# 4467  04:04     79      73        52             0     96       0    10
# 4468  04:22     73      88        18            86     91       0    60
# 4469  02:58     52      91         0             0     96       0    10
# 4470  02:42     68      53        41             0     58       0     0
#
#       Loud (Db)          Key Camelot         Artist_Clean  \
# 0           -11        A#/B♭      6B         Bronski Beat
# 1            -6  A#/B♭ minor      3A           Elton John
# 2            -8            C      8B           Lipps Inc.
# 3            -6        G#/A♭      4B  The Pointer Sisters
# 4           -14        A#/B♭      6B       Modern Talking
# ...         ...          ...     ...                  ...
# 4466        -13        C♯/D♭      3B      Michael Jackson
# 4467         -5            F      7B        Hot Chocolate
# 4468         -7      B minor     10A               T. Rex
# 4469         -4            F      7B          Billy Ocean
# 4470         -9            D     10B          Johnny Nash
#
#                          Song_Clean                                Genre Tags  \
# 0                     Smalltown Boy   80s, new wave, synthpop, pop, synth pop
# 1                I'm Still Standing  pop, 80s, elton john, rock, classic rock
# 2                        Funky Town               Disco, 80s, pop, 70s, dance
# 3                    I'm So Excited              80s, Disco, pop, dance, soul
# 4                  Cheri Cheri Lady    80s, Disco, pop, Modern Talking, dance
# ...                             ...                                       ...
# 4466                  Rock with You   pop, michael jackson, 80s, Disco, dance
# 4467                 You Sexy Thing               Disco, 70s, funk, soul, pop
# 4468                      Get It On  glam rock, 70s, classic rock, rock, glam
# 4469  Love Really Hurts Without You                80s, pop, soul, 70s, Disco
# 4470          I Can See Clearly Now            reggae, 70s, pop, oldies, soul
#
#                                                  lyrics
# 0     To your soul\nTo your soul\nCry\nCry\nCry\n\nY...
# 1     You could never know what it's like\nYour bloo...
# 2     Gotta make a move to a town that's right for m...
# 3     Tonight's the night we're gonna make it happen...
# 4     Oh, I cannot explain\nEvery time, it's the sam...
# ...                                                 ...
# 4466  Girl, close your eyes\nLet that rhythm get int...
# 4467  I believe in miracles\nWhere're you from?\nYou...
# 4468  Well, you're dirty and sweet\nClad in black, d...
# 4469  You run around town like a fool and you think ...
# 4470  I can see clearly now the rain is gone\nI can ...
#
# [4471 rows x 19 columns]

# %%
from IPython.display import display, HTML

# Your filtered and sorted DataFrame
duplicates = df[df['Song'].duplicated(keep=False)]
duplicates = duplicates[['Song', 'Artist']].sort_values(by='Song')


display(HTML(f"""
<div style="height: 300px; overflow-y: scroll; border: 1px solid #ccc; padding: 10px">
{duplicates.to_html(index=False)}
</div>
"""))
# Out:
# <div style="height: 300px; overflow-y: scroll; border: 1px solid #ccc; padding: 10px">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Song</th>
#       <th>Artist</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>23</td>
#       <td>Wallice</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>Mike WiLL Made-It,Miley Cyrus,Wiz Khalifa,Juicy J</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>NLE Choppa</td>
#     </tr>
#     <tr>
#       <td>Afraid</td>
#       <td>The Neighbourhood</td>
#     </tr>
#     <tr>
#       <td>Afraid</td>
#       <td>Nico</td>
#     </tr>
#     <tr>
#       <td>After Hours</td>
#       <td>The Weeknd</td>
#     </tr>
#     <tr>
#       <td>After Hours</td>
#       <td>The Velvet Underground</td>
#     </tr>
#     <tr>
#       <td>Ain't No Sunshine</td>
#       <td>Bill Withers</td>
#     </tr>
#     <tr>
#       <td>Ain't No Sunshine</td>
#       <td>Michael Jackson</td>
#     </tr>
#     <tr>
#       <td>Alive</td>
#       <td>Empire Of The Sun</td>
#     </tr>
#     <tr>
#       <td>Alive</td>
#       <td>Krewella</td>
#     </tr>
#     <tr>
#       <td>Alive</td>
#       <td>Dabin,RUNN</td>
#     </tr>
#     <tr>
#       <td>Alive</td>
#       <td>Pearl Jam</td>
#     </tr>
#     <tr>
#       <td>All Along the Watchtower</td>
#       <td>Jimi Hendrix</td>
#     </tr>
#     <tr>
#       <td>All Along the Watchtower</td>
#       <td>Bob Dylan</td>
#     </tr>
#     <tr>
#       <td>All My Love</td>
#       <td>Noah Kahan</td>
#     </tr>
#     <tr>
#       <td>All My Love</td>
#       <td>Major Lazer,Ariana Grande</td>
#     </tr>
#     <tr>
#       <td>All The Things She Said</td>
#       <td>Simple Minds</td>
#     </tr>
#     <tr>
#       <td>All The Things She Said</td>
#       <td>t.A.T.u.</td>
#     </tr>
#     <tr>
#       <td>Alright</td>
#       <td>Kendrick Lamar</td>
#     </tr>
#     <tr>
#       <td>Alright</td>
#       <td>Supergrass</td>
#     </tr>
#     <tr>
#       <td>Always Forever</td>
#       <td>Bryson Tiller</td>
#     </tr>
#     <tr>
#       <td>Always Forever</td>
#       <td>Cults</td>
#     </tr>
#     <tr>
#       <td>Animal</td>
#       <td>Neon Trees</td>
#     </tr>
#     <tr>
#       <td>Animal</td>
#       <td>Sir Chloe</td>
#     </tr>
#     <tr>
#       <td>Animal</td>
#       <td>Miike Snow</td>
#     </tr>
#     <tr>
#       <td>Apologize</td>
#       <td>OneRepublic</td>
#     </tr>
#     <tr>
#       <td>Apologize</td>
#       <td>Timbaland,OneRepublic</td>
#     </tr>
#     <tr>
#       <td>Believer</td>
#       <td>Major Lazer,Showtek</td>
#     </tr>
#     <tr>
#       <td>Believer</td>
#       <td>Imagine Dragons</td>
#     </tr>
#     <tr>
#       <td>Best Friend</td>
#       <td>Rex Orange County</td>
#     </tr>
#     <tr>
#       <td>Best Friend</td>
#       <td>50 Cent</td>
#     </tr>
#     <tr>
#       <td>Better Together</td>
#       <td>Luke Combs</td>
#     </tr>
#     <tr>
#       <td>Better Together</td>
#       <td>Jack Johnson</td>
#     </tr>
#     <tr>
#       <td>Borderline</td>
#       <td>Madonna</td>
#     </tr>
#     <tr>
#       <td>Borderline</td>
#       <td>Tame Impala</td>
#     </tr>
#     <tr>
#       <td>Boyfriend</td>
#       <td>Dove Cameron</td>
#     </tr>
#     <tr>
#       <td>Boyfriend</td>
#       <td>Best Coast</td>
#     </tr>
#     <tr>
#       <td>Break Your Heart</td>
#       <td>Taio Cruz,Ludacris</td>
#     </tr>
#     <tr>
#       <td>Break Your Heart</td>
#       <td>Taio Cruz</td>
#     </tr>
#     <tr>
#       <td>Buttercup</td>
#       <td>Hippo Campus</td>
#     </tr>
#     <tr>
#       <td>Buttercup</td>
#       <td>Jack Stauber</td>
#     </tr>
#     <tr>
#       <td>Butterfly</td>
#       <td>Grimes</td>
#     </tr>
#     <tr>
#       <td>Butterfly</td>
#       <td>Crazy Town</td>
#     </tr>
#     <tr>
#       <td>Closer</td>
#       <td>Tegan and Sara</td>
#     </tr>
#     <tr>
#       <td>Closer</td>
#       <td>Nine Inch Nails</td>
#     </tr>
#     <tr>
#       <td>Closer</td>
#       <td>Ne-Yo</td>
#     </tr>
#     <tr>
#       <td>Closer</td>
#       <td>The Chainsmokers,Halsey</td>
#     </tr>
#     <tr>
#       <td>Colors</td>
#       <td>Hardwell,Tiësto,Andreas Moe</td>
#     </tr>
#     <tr>
#       <td>Colors</td>
#       <td>Black Pumas</td>
#     </tr>
#     <tr>
#       <td>Crazy</td>
#       <td>Gnarls Barkley</td>
#     </tr>
#     <tr>
#       <td>Crazy</td>
#       <td>Aerosmith</td>
#     </tr>
#     <tr>
#       <td>Crying</td>
#       <td>Don McLean</td>
#     </tr>
#     <tr>
#       <td>Crying</td>
#       <td>Roy Orbison</td>
#     </tr>
#     <tr>
#       <td>Dangerous</td>
#       <td>Kardinal Offishall,Akon</td>
#     </tr>
#     <tr>
#       <td>Dangerous</td>
#       <td>Morgan Wallen</td>
#     </tr>
#     <tr>
#       <td>Daniel</td>
#       <td>Elton John</td>
#     </tr>
#     <tr>
#       <td>Daniel</td>
#       <td>Bat For Lashes</td>
#     </tr>
#     <tr>
#       <td>Daylight</td>
#       <td>Maroon 5</td>
#     </tr>
#     <tr>
#       <td>Daylight</td>
#       <td>David Kushner</td>
#     </tr>
#     <tr>
#       <td>Daylight</td>
#       <td>Harry Styles</td>
#     </tr>
#     <tr>
#       <td>Die For You</td>
#       <td>Joji</td>
#     </tr>
#     <tr>
#       <td>Die For You</td>
#       <td>The Weeknd</td>
#     </tr>
#     <tr>
#       <td>Die Young</td>
#       <td>Sylvan Esso</td>
#     </tr>
#     <tr>
#       <td>Die Young</td>
#       <td>Kesha</td>
#     </tr>
#     <tr>
#       <td>Don't</td>
#       <td>Bryson Tiller</td>
#     </tr>
#     <tr>
#       <td>Don't</td>
#       <td>Ed Sheeran</td>
#     </tr>
#     <tr>
#       <td>Dynamite</td>
#       <td>Taio Cruz</td>
#     </tr>
#     <tr>
#       <td>Dynamite</td>
#       <td>BTS</td>
#     </tr>
#     <tr>
#       <td>Everytime</td>
#       <td>Britney Spears</td>
#     </tr>
#     <tr>
#       <td>Everytime</td>
#       <td>boy pablo</td>
#     </tr>
#     <tr>
#       <td>Faded</td>
#       <td>ZHU</td>
#     </tr>
#     <tr>
#       <td>Faded</td>
#       <td>Alan Walker</td>
#     </tr>
#     <tr>
#       <td>Fast Car</td>
#       <td>Tracy Chapman</td>
#     </tr>
#     <tr>
#       <td>Fast Car</td>
#       <td>Jonas Blue,Dakota</td>
#     </tr>
#     <tr>
#       <td>Fast Car</td>
#       <td>Luke Combs</td>
#     </tr>
#     <tr>
#       <td>Fine Line</td>
#       <td>Mabel,Not3s</td>
#     </tr>
#     <tr>
#       <td>Fine Line</td>
#       <td>Harry Styles</td>
#     </tr>
#     <tr>
#       <td>Finesse</td>
#       <td>Drake</td>
#     </tr>
#     <tr>
#       <td>Finesse</td>
#       <td>Bruno Mars</td>
#     </tr>
#     <tr>
#       <td>For the First Time</td>
#       <td>Mac DeMarco</td>
#     </tr>
#     <tr>
#       <td>For the First Time</td>
#       <td>The Script</td>
#     </tr>
#     <tr>
#       <td>Get Low</td>
#       <td>Dillon Francis,DJ Snake</td>
#     </tr>
#     <tr>
#       <td>Get Low</td>
#       <td>Lil Jon &amp; The East Side Boyz,Ying Yang Twins</td>
#     </tr>
#     <tr>
#       <td>Gloria</td>
#       <td>The Lumineers</td>
#     </tr>
#     <tr>
#       <td>Gloria</td>
#       <td>Laura Branigan</td>
#     </tr>
#     <tr>
#       <td>Gold</td>
#       <td>Dierks Bentley</td>
#     </tr>
#     <tr>
#       <td>Gold</td>
#       <td>Dash Berlin,Dbstf,Jake Reese,Waka Flocka Flame,DJ Whoo Kid</td>
#     </tr>
#     <tr>
#       <td>Gold</td>
#       <td>Kiiara</td>
#     </tr>
#     <tr>
#       <td>Good Life</td>
#       <td>Inner City</td>
#     </tr>
#     <tr>
#       <td>Good Life</td>
#       <td>OneRepublic</td>
#     </tr>
#     <tr>
#       <td>Good Time</td>
#       <td>Owl City,Carly Rae Jepsen</td>
#     </tr>
#     <tr>
#       <td>Good Time</td>
#       <td>Alan Jackson</td>
#     </tr>
#     <tr>
#       <td>Gypsy</td>
#       <td>Lady Gaga</td>
#     </tr>
#     <tr>
#       <td>Gypsy</td>
#       <td>Fleetwood Mac</td>
#     </tr>
#     <tr>
#       <td>Happier Than Ever</td>
#       <td>ASTN</td>
#     </tr>
#     <tr>
#       <td>Happier Than Ever</td>
#       <td>Billie Eilish</td>
#     </tr>
#     <tr>
#       <td>Harvey</td>
#       <td>Her's</td>
#     </tr>
#     <tr>
#       <td>Harvey</td>
#       <td>Alex G</td>
#     </tr>
#     <tr>
#       <td>Heartbreaker</td>
#       <td>Dionne Warwick</td>
#     </tr>
#     <tr>
#       <td>Heartbreaker</td>
#       <td>Pat Benatar</td>
#     </tr>
#     <tr>
#       <td>Heartless</td>
#       <td>The Weeknd</td>
#     </tr>
#     <tr>
#       <td>Heartless</td>
#       <td>Kanye West</td>
#     </tr>
#     <tr>
#       <td>Heaven</td>
#       <td>Jason Aldean</td>
#     </tr>
#     <tr>
#       <td>Heaven</td>
#       <td>Niall Horan</td>
#     </tr>
#     <tr>
#       <td>Heaven</td>
#       <td>Avicii</td>
#     </tr>
#     <tr>
#       <td>Heaven</td>
#       <td>Bryan Adams<

# %% [markdown]
# The following will be removed as song duplicates with the same artists: apologize (4249), break your heart (2636), sativa (4139). The song Fast Car had three different renditions but will keep only the original and remove: fast car (359, 2971)

# %%
rows_to_remove = [4249, 2636, 4139, 359, 2971]  # row numbers (zero-based)
df = df.drop(index=df.index[rows_to_remove])
df = df.reset_index(drop=True)

# %%
df.describe(include='object')
# Out:
#           Song        Artist   Time   Key Camelot Artist_Clean Song_Clean  \
# count     4466          4466   4115  4466    4466         4466       4466
# unique    4299          2005    356    24      24         1632       4271
# top     Heaven  Taylor Swift  03:29     C      8B        Drake     Closer
# freq         4            49     45   428     428           66          4
#
#            Genre Tags                                             lyrics
# count            4466                                               4466
# unique           4172                                               4466
# top     Bryson Tiller  To your soul\nTo your soul\nCry\nCry\nCry\n\nY...
# freq               12                                                  1

# %% [markdown]
# Will have to figure out what to do with genre tags as the majority of songs have 5 tags. Split them up into individual columns? Aggregate into most common tag? Unsure right now...

# %% [markdown]
# Now the difference between unique songs and unique song_clean are also likely duplicates with songs that have recently been "Remastered"

# %%
# Group by the cleaned song name
grouped = df.groupby('Song_Clean')['Song'].nunique()

# Filter where more than one distinct 'song' maps to a single 'song_clean'
duplicates = grouped[grouped > 1]

# Now view those entries
df[df['Song_Clean'].isin(duplicates.index)][['Song_Clean', 'Song', 'Artist', 'Popularity']].sort_values(by='Song_Clean')
# Out:
#                                 Song_Clean  \
# 1362              The Show Must Go On - Remastered 2011
# 3945                                The Show Must Go On
# 367                                          Wake Me Up
# 491                             Wake Me Up - Radio Edit
# 2552                    Waves - Robin Schulz Radio Edit
# 2853                                              Waves
# 3294                                              Waves
# 1191      What's Love Got to Do with It - 2015 Remaster
# 252                       What's Love Got to Do with It
# 115                                       White Wedding
# 3951                              White Wedding - Pt. 1
# 1401                           Wicked Game - Remastered
# 262                                         Wicked Game
# 221                   Wuthering Heights - 2018 Remaster
# 1580                                  Wuthering Heights
#
#                        Artist  Popularity
# 3841    2 Chainz,Travis Scott          62
# 314                   Kaskade          51
# 3947                    Queen           1
# 190                     Queen          84
# 180                 Kate Bush          65
# 1900                Kate Bush          61
# 894              Hippo Campus           0
# 188                   Sabrina          66
# 3579               The Weeknd          80
# 3583               The Weeknd          52
# 120                The Police           2
# 3926               The Police          79
# 1855             Donna Summer          66
# 3669             Donna Summer          71
# 522             Calvin Harris          50
# 400             Calvin Harris          62
# 3747                The Kinks           2
# 4325                The Kinks           4
# 3684               The Police           0
# 1389               The Police          80
# 2772        Justin Timberlake          85
# 2346        Justin Timberlake          64
# 2722   Jennifer Lopez,Pitbull          84
# 2444   Jennifer Lopez,Pitbull          78
# 1516  Daryl Hall & John Oates          53
# 50    Daryl Hall & John Oates          66
# 2029               The Police           1
# 1320               The Police          81
# 3753               Thin Lizzy          42
# 1499                   Alex G           0
# 3768           Peter Frampton          55
# 1888           Peter Frampton          68
# 302                    Avicii          69
# 599              Colony House           0
# 561         CAZZETTE,The High           0
# 552     Flume,Jezzabell Doran           0
# 3942                       U2          47
# 1425                       U2          74
# 4299           The Beach Boys          73
# 1977           The Beach Boys          62
# 4306             The Box Tops          70
# 4324               Joe Cocker          47
# 1362                    Queen          72
# 3945                    Queen           0
# 367                    Avicii          17
# 491                    Avicii           9
# 2552   Mr. Probz,Robin Schulz          11
# 2853               Luke Bryan          59
# 3294               Kanye West          71
# 1191              Tina Turner          72
# 252               Tina Turner          59
# 115                Billy Idol          63
# 3951               Billy Idol          76
# 1401              Chris Isaak          61
# 262               Chris Isaak           0
# 221                 Kate Bush          41
# 1580                Kate Bush          69

# %% [markdown]
# Again, will be removing the version with the lowest popularity

# %%
rows_to_remove = [314, 3947, 1900, 3583, 120, 1855, 522, 3747, 3684, 2346, 2444, 1516, 2029, 3768, 3942, 1977, 3945, 491, 252, 115, 262, 221]  # row numbers (zero-based)
df = df.drop(index=df.index[rows_to_remove])
df = df.reset_index(drop=True)

# %% [markdown]
# Upon further investigation, Key and Camelot seem to be the exact same thing just in different notation. Will run Cramer's V categorical correlation to confirm this, and if score is one will remove Key from the dataset

# %%
import numpy as np
from scipy.stats import chi2_contingency

def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x, y)
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2_corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))  # bias correction
    r_corr = r - ((r-1)**2)/(n-1)
    k_corr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2_corr / min((k_corr-1), (r_corr-1)))

cramers_v(df['Key'], df['Camelot'])
# Out:
# np.float64(1.0)

# %%
df = df.drop(columns=['Key'])

# %% [markdown]
# Decided to remove songs without time

# %%
df = df[df['Time'].notnull()]
df = df.reset_index(drop=True)

# %%
df.describe()
# Out:
#         Popularity          BPM        Dance       Energy     Acoustic  \
# count  4095.000000  4095.000000  4095.000000  4095.000000  4095.000000
# mean     55.791941   121.874237    58.752137    64.345543    23.575092
# std      26.804056    27.528039    14.856005    20.020007    26.478502
# min       0.000000    49.000000     9.000000     3.000000     0.000000
# 25%      47.000000   101.000000    49.000000    51.000000     2.000000
# 50%      65.000000   121.000000    59.000000    67.000000    12.000000
# 75%      75.000000   138.000000    69.000000    80.000000    38.000000
# max     100.000000   219.000000    96.000000   100.000000    99.000000
#
#              Happy         Live    Loud (Db)  time_seconds  time_bucket
# count  4095.000000  4095.000000  4095.000000   4095.000000  4095.000000
# mean     52.212698    13.645910    -7.638584    231.944078   227.518926
# std      24.392731    14.494129     3.436389     62.953950    63.011836
# min       3.000000     0.000000   -26.000000     73.000000    70.000000
# 25%      33.000000     0.000000   -10.000000    193.000000   190.000000
# 50%      52.000000    10.000000    -7.000000    223.000000   220.000000
# 75%      72.000000    20.000000    -5.000000    261.500000   260.000000
# max      99.000000    90.000000    -1.000000    685.000000   680.000000

# %% [markdown]
# Maybe think about removing instrumental and speech from the feature space as their standard deviations are far higher than their means?

# %% [markdown]
# Now will look at distributions of the numeric features, hoping to see somewhat normal distributions for many of these...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select numeric columns only
numeric_cols = df.select_dtypes(include=['number']).columns

# Set up the plotting grid — adjust size as needed
n_cols = 3  # number of plots per row
n_rows = (len(numeric_cols) + n_cols - 1) // n_cols

plt.figure(figsize=(5 * n_cols, 4 * n_rows))

for i, col in enumerate(numeric_cols, 1):
    plt.subplot(n_rows, n_cols, i)
    sns.histplot(df[col].dropna(), kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# Getting rid of instrumental and speech as features

# %%
df = df.drop(columns=['Instrumental', 'Speech'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df = df.drop(columns=['Instrumental', 'Speech'])
#
# File /opt/anaconda3/envs/ml/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File /opt/anaconda3/envs/ml/lib/python3.12/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File /opt/anaconda3/envs/ml/lib/python3.12/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File /opt/anaconda3/envs/ml/lib/python3.12/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Instrumental', 'Speech'] not found in axis"

# %% [markdown]
# Maybe remove low popularity songs from the set? In looking at the data some very popular songs how low popularity scores and this could heavily skew the model output. Removing songs with a popularity below 15-20 will give us a normal distribution of popularity scores

# %%
filtered_songs = df[(df['Popularity'] >= 15) & (df['Popularity'] <= 20)]

# Display relevant columns (you can add/remove columns as needed)
filtered_songs[['Song', 'Artist', 'Popularity']].sort_values(by='Popularity')
# Out:
#                          Song               Artist  Popularity
# 94              Paradise City        Guns N' Roses          15
# 2741       Sleep On The Floor        The Lumineers          15
# 516         Take Over Control  AFROJACK,Eva Simons          15
# 943           Mary On A Cross                Ghost          15
# 1968               Lazy Susan           Laura Nyro          15
# 1033                  Blondie         Current Joys          16
# 1977              Goodbye Joe           Laura Nyro          16
# 2147   The Limit To Your Love                Feist          16
# 102      Don't Stop Believin'              Journey          17
# 361                Wake Me Up               Avicii          17
# 2695                      Les     Childish Gambino          18
# 2757      MILLION DOLLAR BABY        Tommy Richman          18
# 70        Sweet Child O' Mine        Guns N' Roses          19
# 3960         Groovy Situation        Gene Chandler          19
# 527                    Fences  Vicetone,Matt Wertz          20
# 282   The Lion Sleeps Tonight            Tight Fit          20
# 1985           And When I Die           Laura Nyro          20

# %% [markdown]
# Finally, will look at who is in the data...

# %%
top_artists = df['Artist'].value_counts().head(20)

print(top_artists)
# Out:
# Artist
# Taylor Swift         43
# Morgan Wallen        42
# Drake                40
# The Weeknd           32
# Bryson Tiller        25
# Luke Combs           24
# Billy Joel           24
# Wallows              23
# Zach Bryan           20
# Bob Dylan            20
# ABBA                 17
# Arctic Monkeys       16
# Kanye West           16
# Frank Ocean          16
# Coldplay             16
# Mitski               15
# Avicii               15
# Rex Orange County    15
# Lana Del Rey         15
# Pink Floyd           14
# Name: count, dtype: int64

# %%
top_artists_clean = df['Artist_Clean'].value_counts().head(20)

print(top_artists_clean)
# Out:
# Artist_Clean
# Drake                55
# Morgan Wallen        46
# Taylor Swift         44
# The Weeknd           32
# Luke Combs           26
# Bryson Tiller        25
# Billy Joel           24
# Wallows              23
# Zach Bryan           20
# Bob Dylan            20
# Kanye West           20
# Frank Ocean          18
# ABBA                 17
# Coldplay             17
# Avicii               17
# Rex Orange County    16
# Lana Del Rey         16
# PARTYNEXTDOOR        16
# Arctic Monkeys       16
# Martin Garrix        15
# Name: count, dtype: int64

# %%
top_artists = df['Camelot'].value_counts().head(24)

print(top_artists)
# Out:
# Camelot
# 8B     393
# 10B    365
# 9B     340
# 11B    292
# 3B     267
# 7B     232
# 10A    175
# 4B     173
# 2B     168
# 12B    160
# 1B     156
# 9A     141
# 6B     141
# 3A     135
# 11A    133
# 8A     129
# 4A     127
# 12A    120
# 6A     104
# 5A      92
# 5B      92
# 1A      64
# 7A      60
# 2A      36
# Name: count, dtype: int64

# %% [markdown]
# Lastly, convert time to a number and view

# %%
def time_to_seconds(t):
    try:
        minutes, seconds = map(int, t.split(':'))
        return minutes * 60 + seconds
    except:
        return None  # Handle bad formats gracefully

df['time_seconds'] = df['Time'].apply(time_to_seconds)

# Step 2: Create 10-second buckets
df['time_bucket'] = (df['time_seconds'] // 10) * 10

# Step 3: Plot distribution of time buckets
bucket_counts = df['time_bucket'].value_counts().sort_index()

plt.figure(figsize=(12, 6))
sns.barplot(x=bucket_counts.index, y=bucket_counts.values, color='skyblue')
plt.title('Song Duration Distribution (10-second buckets)')
plt.xlabel('Duration (seconds, grouped by 10s)')
plt.ylabel('Number of Songs')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.shape
# Out:
# (4095, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4095 entries, 0 to 4094
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Song          4095 non-null   object
#  1   Artist        4095 non-null   object
#  2   Popularity    4095 non-null   int64
#  3   BPM           4095 non-null   int64
#  4   Time          4095 non-null   object
#  5   Dance         4095 non-null   int64
#  6   Energy        4095 non-null   int64
#  7   Acoustic      4095 non-null   int64
#  8   Happy         4095 non-null   int64
#  9   Live          4095 non-null   int64
#  10  Loud (Db)     4095 non-null   int64
#  11  Camelot       4095 non-null   object
#  12  Artist_Clean  4095 non-null   object
#  13  Song_Clean    4095 non-null   object
#  14  Genre Tags    4095 non-null   object
#  15  lyrics        4095 non-null   object
#  16  time_seconds  4095 non-null   int64
#  17  time_bucket   4095 non-null   int64
# dtypes: int64(10), object(8)
# memory usage: 576.0+ KB

# %%
df.to_csv('week_2_final_dataset.csv', index=False)
