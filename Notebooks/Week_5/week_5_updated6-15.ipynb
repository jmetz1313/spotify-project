# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Ryan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import re
import spacy
from nltk.corpus import stopwords

# %%
df = pd.read_csv('Week_3/week_3_final_dataset.csv')

# %% [markdown]
# Removing the Live and Time columns as we no longer want to use it

# %%
df = df.drop(columns=['Live', 'Time'])

# %% [markdown]
# Slightly altered the week 3 eda notebook to re-catagorize subgenres that had fewer than 15 instances, now only 42 total subgenres exist

# %%
subgenre_counts = df['Subgenre'].value_counts()
subgenre_counts
# Out:
# Subgenre
# hip hop              272
# indie rock           207
# indie pop            203
# pop 80s              168
# alternative rock     163
# rock 70s             148
# rock 80s             144
# country              130
# pop                  124
# rock                 119
# electronic            88
# rnb                   86
# pop rock              75
# folk                  67
# country pop           63
# indie                 62
# alternative           59
# rock 60s              54
# alternative rnb       51
# dance                 49
# indie folk            48
# dance pop             46
# pop dance             46
# pop 70s               46
# soul                  45
# folk rock             45
# rock alternative      43
# hip hop rnb           36
# soul 70s              35
# rock 90s              31
# electronic pop        28
# pop 90s               27
# electronic dance      27
# soul rnb              23
# pop 60s               22
# pop rnb               19
# hip hop 90s           19
# indie alternative     19
# pop synthpop          19
# soul 80s              18
# dance electronic      16
# soul 60s              16
# soul disco            15
# Name: count, dtype: int64

# %% [markdown]
# Preparing the data for tokenization by cleaning the lyrics, also removing stop words and lemanizing the lyrics

# %%
# Load spaCy model and stopwords
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])
stop_words = set(stopwords.words("english"))

def clean_lyrics(text):
    if pd.isnull(text):
        return ""

    # Lowercase
    text = text.lower()

    # Remove HTML tags
    text = re.sub(r"<.*?>", "", text)

    # Remove [annotations like chorus/verse]
    text = re.sub(r"\[.*?\]", "", text)

    # Remove all punctuation (including apostrophes) - modification from week 4 to 5.
    text = re.sub(r"[^a-z0-9\s]", "", text)

    # Remove extra whitespace
    text = re.sub(r"\s+", " ", text).strip()

    # Tokenize with spaCy
    doc = nlp(text)

    # Lemmatize and remove stopwords
    tokens = [token.lemma_ for token in doc if token.text not in stop_words and token.lemma_ not in stop_words]

    return " ".join(tokens)

# %%
df['Clean_Lyrics'] = df['Lyrics'].apply(clean_lyrics)

# %%
df = df.drop(columns='Lyrics')

# %%
df
# Out:
#                                    Song                  Artist  Popularity  \
# 0                        I'm So Excited     The Pointer Sisters          65
# 1                      Cheri Cheri Lady          Modern Talking          82
# 2                            Give It Up  KC & The Sunshine Band          58
# 3     It's Raining Men - Single Version       The Weather Girls          50
# 4                            Take on Me                    a-ha          89
# ...                                 ...                     ...         ...
# 3016              Play That Funky Music             Wild Cherry          76
# 3017     Rock with You - Single Version         Michael Jackson          82
# 3018                     You Sexy Thing           Hot Chocolate          75
# 3019                          Get It On                  T. Rex          72
# 3020              I Can See Clearly Now             Johnny Nash          51
#
#       BPM  Dance  Energy  Acoustic  Happy  Loud Camelot Genre    Subgenre  \
# 0      92     69      86        10     69    -6      4B   pop     pop 80s
# 1     114     68      62        46     85   -14      6B   pop     pop 80s
# 2     126     84      65         8     84   -12      5B   pop         pop
# 3     136     66      93        46     46    -6      4A   pop         pop
# 4      84     57      90         2     88    -8     11A   pop     pop 80s
# ...   ...    ...     ...       ...    ...   ...     ...   ...         ...
# 3016  109     81      67         4     93   -12     11B  soul  soul disco
# 3017  114     81      54        18     85   -13      3B   pop     pop 80s
# 3018  106     79      73        52     96    -5      7B  soul  soul disco
# 3019  127     73      88        18     91    -7     10A  rock    rock 70s
# 3020  124     68      53        41     58    -9     10B   pop     pop 70s
#
#                                            Clean_Lyrics
# 0     tonight night go make happen tonight well put ...
# 1     oh explain every time oh feel real take heart ...
# 2     everybody want everybody want love like make m...
# 3     hi hi weather girl uh huh get news well listen...
# 4     talk away know say ill say anyway today anothe...
# ...                                                 ...
# 3016  ahey huh yeah hey heyah boogie singer playing ...
# 3017  girl close eye let rhythm get try fight nothin...
# 3018  believe miracle sexy thing sexy thing believe ...
# 3019  well dirty sweet clad black look back love dir...
# 3020  see clearly rain go see obstacle way go dark c...
#
# [3021 rows x 13 columns]

# %% [markdown]
# Add interaction feature 'Power' before data splitting. Power = loud x energy.
# Loud and energy have a high correlation coefficient:0.73, making it a good candidate for an interaction term.

# %%
# Add interaction term 'Power': Power = Loud * Energy
df['Power'] = df['Loud'] * df['Energy']

# %% [markdown]
# Split the data before feature normalization to prevent data leakage.

# %%
# Split data
df_train, temp_df = train_test_split(df, test_size=0.3, random_state=42)
df_val, df_test = train_test_split(temp_df, test_size=0.5, random_state=42)

# %% [markdown]
# Normalizing the numeric features on a 0 to 1 scale. Perform the normalization on the training data first. Then use the scalers from the training transformation to normalize the test and validation sets. This will prevent data leakage and prevent the model from over performing.

# %%
# Select only numeric columns
numeric_cols = df_train.select_dtypes(include='number').columns

# Create a scaler and fit-transform the numeric columns
scaler = MinMaxScaler()
df_train[numeric_cols] = scaler.fit_transform(df_train[numeric_cols])

# %%
# Calculate the scaled means
scaled_means = df_train[numeric_cols].mean()

# Create a scaler summary DataFrame
scaler_summary = pd.DataFrame({
    'feature': numeric_cols,
    'original_min': scaler.data_min_,
    'original_max': scaler.data_max_,
    'scaler': scaler.scale_,          # 1 / (max - min)
    'scaled_mean': scaled_means.values
})

# Display
scaler_summary.set_index('feature', inplace=True)
display(scaler_summary)
# Out:
#             original_min  original_max    scaler  scaled_mean
# feature
# Popularity          20.0         100.0  0.012500     0.588476
# BPM                 49.0         219.0  0.005882     0.424823
# Dance               11.0          96.0  0.011765     0.565006
# Energy               5.0         100.0  0.010526     0.624075
# Acoustic             0.0          99.0  0.010101     0.235639
# Happy                3.0          98.0  0.010526     0.525564
# Loud               -26.0          -1.0  0.040000     0.731693
# Power            -1036.0         -70.0  0.001035     0.611998

# %%
# Apply the same transformation to validation and test sets
df_val[numeric_cols] = scaler.transform(df_val[numeric_cols])
df_test[numeric_cols] = scaler.transform(df_test[numeric_cols])

# %%
# Save to CSV
df_train.to_csv("Week_4/week_4_train_set.csv", index=False)
df_test.to_csv("Week_4/week_4_test_set.csv", index=False)
df_val.to_csv("Week_4/week_4_validation_set.csv", index=False)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder

import nltk
from nltk.tokenize import word_tokenize
# !pip install gensim

from gensim.models.fasttext import load_facebook_vectors
from gensim.models import KeyedVectors
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp310-cp310-win_amd64.whl.metadata (8.2 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\ryan\anaconda3\envs\final_project\lib\site-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in c:\users\ryan\anaconda3\envs\final_project\lib\site-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Downloading gensim-4.3.3-cp310-cp310-win_amd64.whl (24.0 MB)
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ---- ----------------------------------- 2.9/24.0 MB 13.9 MB/s eta 0:00:02
#    -------------- ------------------------- 8.7/24.0 MB 21.5 MB/s eta 0:00:01
#    -------------------------- ------------- 15.7/24.0 MB 26.0 MB/s eta 0:00:01
#    -------------------------------------- - 23.3/24.0 MB 28.9 MB/s eta 0:00:01
#    ---------------------------------------- 24.0/24.0 MB 25.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ----------------- ---------------------- 7.1/15.8 MB 39.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.2/15.8 MB 35.6 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 31.1 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp310-cp310-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ------ --------------------------------- 7.1/46.2 MB 36.3 MB/s eta 0:00:02
#    ------------ --------------------------- 14.4/46.2 MB 36.2 MB/s eta 0:00:01
#    ------------------- -------------------- 22.3/46.2 MB 37.1 MB/s eta 0:00:01
#    -------------------------- ------------- 30.1/46.2 MB 37.5 MB/s eta 0:00:01
#    -------------------------------- ------- 38.0/46.2 MB 37.7 MB/s eta 0:00:01
#    ---------------------------------------  46.1/46.2 MB 38.1 MB/s eta 0:00:01
#    ---------------------------------------  46.1/46.2 MB 38.1 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 31.6 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 2.2.6
#
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#     Uninstalling numpy-2.2.6:
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#       Successfully uninstalled numpy-2.2.6
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#   Attempting uninstall: scipy
#    ---------------------------------------- 0/3 [numpy]
#     Found existing installation: scipy 1.15.3
#    ---------------------------------------- 0/3 [numpy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#     Uninstalling scipy-1.15.3:
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#       Successfully uninstalled scipy-1.15.3
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    ------------- -------------------------- 1/3 [scipy]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    -------------------------- ------------- 2/3 [gensim]
#    ---------------------------------------- 3/3 [gensim]
#
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Ryan\AppData\Local\Temp\pip-uninstall-wf41_67k'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Ryan\anaconda3\envs\final_project\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Ryan\anaconda3\envs\final_project\Lib\site-packages\~cipy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Ryan\anaconda3\envs\final_project\Lib\site-packages\~cipy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 9
#       6 from nltk.tokenize import word_tokenize
#       7 get_ipython().system('pip install gensim')
# ----> 9 from gensim.models.fasttext import load_facebook_vectors
#      10 from gensim.models import KeyedVectors
#
# File ~\anaconda3\envs\final_project\lib\site-packages\gensim\__init__.py:11
#       7 __version__ = '4.3.3'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File ~\anaconda3\envs\final_project\lib\site-packages\gensim\corpora\__init__.py:6
#       1 """
#       2 This package contains implementations of various streaming corpus I/O format.
#       3 """
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#       9 from .bleicorpus import BleiCorpus  # noqa:F401
#
# File ~\anaconda3\envs\final_project\lib\site-packages\gensim\corpora\indexedcorpus.py:14
#      10 import logging
#      12 import numpy
# ---> 14 from gensim import interfaces, utils
#      16 logger = logging.getLogger(__name__)
#      19 class IndexedCorpus(interfaces.CorpusABC):
#
# File ~\anaconda3\envs\final_project\lib\site-packages\gensim\interfaces.py:19
#       7 """Basic interfaces used across the whole Gensim package.
#       8
#       9 These interfaces are used for building corpora, model transformation and similarity queries.
#    (...)
#      14
#      15 """
#      17 import logging
# ---> 19 from gensim import utils, matutils
#      22 logger = logging.getLogger(__name__)
#      25 class CorpusABC(utils.SaveLoad):
#
# File ~\anaconda3\envs\final_project\lib\site-packages\gensim\matutils.py:1034
#    1029     return 1. - float(len(set1 & set2)) / float(union_cardinality)
#    1032 try:
#    1033     # try to load fast, cythonized code if possible
# -> 1034     from gensim._matutils import logsumexp, mean_absolute_difference, dirichlet_expectation
#    1036 except ImportError:
#    1037     def logsumexp(x):
#
# File ~\anaconda3\envs\final_project\lib\site-packages\gensim\_matutils.pyx:1, in init gensim._matutils()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
df_train.head()
# Out:
#                                                 Song  \
# 2739  Stretch You Out (feat. A Boogie wit da Hoodie)
# 440                               On Melancholy Hill
# 508                                       WHO CARES?
# 76                                             Solid
# 1947                                   BREAK MY SOUL
#
#                                     Artist  Popularity       BPM     Dance  \
# 2739  Summer Walker,A Boogie Wit da Hoodie        0.50  0.317647  0.623529
# 440                               Gorillaz        0.80  0.417647  0.682353
# 508                      Rex Orange County        0.35  0.217647  0.835294
# 76                       Ashford & Simpson        0.45  0.305882  0.823529
# 1947                               Beyoncé        0.55  0.388235  0.682353
#
#         Energy  Acoustic     Happy  Loud Camelot       Genre    Subgenre  \
# 2739  0.494737  0.252525  0.231579  0.76     12A        soul    soul rnb
# 440   0.726316  0.000000  0.578947  0.80     10B  electronic  electronic
# 508   0.242105  0.595960  0.589474  0.80      4B       indie   indie pop
# 76    0.442105  0.272727  0.978947  0.56      8B        soul    soul 80s
# 1947  0.884211  0.060606  0.863158  0.84     12A       dance   dance pop
#
#                                            Clean_Lyrics     Power
# 2739  get london da track niggas insecure claim enou...  0.695652
# 440   melancholy hill good side consumerism like muc...  0.612836
# 508   mmmm mmmm mmmm mmmm first time try free doubt ...  0.898551
# 76    love sake mistake oh forgave soon learn trust ...  0.488613
# 1947  bout explode take load bend bust open ya make ...  0.611801

# %% [markdown]
# Camelot in practice is a circular scale. We could one hot encode 0-23, but 23 and 0 are just as close on the Camelot scale as 0 and 1. Instead we will code Camelot to have sin and cos coordinates (mapping on the unit circle) to better model songs in latent space.

# %%
#Circular encoding for Camelot

def camelot_to_position(code):
    number = int(code[:-1])   # extract number (1-12)
    mode = code[-1]           # extract mode (A or B)
    mode_offset = 0 if mode == 'A' else 12        # Start at 0 if mode is A, if not start at 13
    return (number - 1) + mode_offset 

def add_sin_cos(df):
    df['camelot_pos'] = df['Camelot'].map(camelot_to_position) #map camelot positions to 0-23
    df['camelot_sin'] = np.sin(2 * np.pi * df['camelot_pos'] / 24)        #compute sine transformation 
    df['camelot_cos'] = np.cos(2 * np.pi * df['camelot_pos'] / 24)        #compute cosine transformation
    df.drop(['Camelot', 'camelot_pos'], axis=1, inplace=True)             #Drop camelot and intermediate position column.
    return df

#Apply transformation to train, test, val sets.
df_train = add_sin_cos(df_train)
df_val = add_sin_cos(df_val)
df_test = add_sin_cos(df_test)

# %% [markdown]
# Create a list of variables that we want to encode

# %%
one_hot_cols = ['Genre', 'Subgenre']

# %%
# One-hot encoder (for Genre and Subgenre)
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encoder.fit(df_train[one_hot_cols])
# Out:
# OneHotEncoder(handle_unknown='ignore', sparse_output=False)

# %%
# Helper function to transform and reattach
def encode_and_concat(df, encoder, categorical_cols):
    encoded = encoder.transform(df[categorical_cols])
    encoded_df = pd.DataFrame(encoded, columns=encoder.get_feature_names_out(categorical_cols), index=df.index)
    return pd.concat([df.drop(one_hot_cols, axis=1), encoded_df], axis=1)

# %%
# Apply to each split
df_train_encoded = encode_and_concat(df_train, encoder, one_hot_cols)
df_val_encoded = encode_and_concat(df_val, encoder, one_hot_cols)
df_test_encoded = encode_and_concat(df_test, encoder, one_hot_cols)

# %%
df_val_encoded.head()
# Out:
#                           Song         Artist  Popularity       BPM     Dance  \
# 1591                Rebel Yell     Billy Idol      0.7375  0.688235  0.494118
# 2472             Lonely People        America      0.5750  0.176471  0.529412
# 88              What A Feeling     Irene Cara      0.6375  0.429412  0.494118
# 1426          Bird on the Wire  Leonard Cohen      0.4000  0.464706  0.341176
# 2937  I'll Say Forever My Love   Jimmy Ruffin      0.1750  0.323529  0.517647
#
#         Energy  Acoustic     Happy  Loud  \
# 1591  0.852632  0.000000  0.484211  0.84
# 2472  0.442105  0.262626  0.557895  0.68
# 88    0.715789  0.383838  0.600000  0.76
# 1426  0.063158  0.848485  0.168421  0.40
# 2937  0.600000  0.010101  0.663158  0.76
#
#                                            Clean_Lyrics  ...  \
# 1591  last night little dancer acame dancin door las...  ...
# 2472  lonely people thinkin life pass give drink sil...  ...
# 88    first nothing slow glow dream fear seem hide d...  ...
# 1426  like bird wire like drunk midnight choir try w...  ...
# 2937  forever forever forever love ill say forever l...  ...
#
#       Subgenre_rock 70s  Subgenre_rock 80s  Subgenre_rock 90s  \
# 1591                0.0                1.0                0.0
# 2472                0.0                0.0                0.0
# 88                  0.0                0.0                0.0
# 1426                0.0                0.0                0.0
# 2937                0.0                0.0                0.0
#
#       Subgenre_rock alternative  Subgenre_soul  Subgenre_soul 60s  \
# 1591                        0.0            0.0                0.0
# 2472                        0.0            0.0                0.0
# 88                          0.0            0.0                0.0
# 1426                        0.0            0.0                0.0
# 2937                        0.0            0.0                1.0
#
#       Subgenre_soul 70s  Subgenre_soul 80s  Subgenre_soul disco  \
# 1591                0.0                0.0                  0.0
# 2472                0.0                0.0                  0.0
# 88                  0.0                0.0                  0.0
# 1426                0.0                0.0                  0.0
# 2937                0.0                0.0                  0.0
#
#       Subgenre_soul rnb
# 1591                0.0
# 2472                0.0
# 88                  0.0
# 1426                0.0
# 2937                0.0
#
# [5 rows x 67 columns]

# %%
list(df_val_encoded.columns)
# Out:
# ['Song',
#  'Artist',
#  'Popularity',
#  'BPM',
#  'Dance',
#  'Energy',
#  'Acoustic',
#  'Happy',
#  'Loud',
#  'Clean_Lyrics',
#  'Power',
#  'camelot_sin',
#  'camelot_cos',
#  'Genre_alternative',
#  'Genre_country',
#  'Genre_dance',
#  'Genre_electronic',
#  'Genre_folk',
#  'Genre_hip hop',
#  'Genre_indie',
#  'Genre_pop',
#  'Genre_rnb',
#  'Genre_rock',
#  'Genre_soul',
#  'Subgenre_alternative',
#  'Subgenre_alternative rnb',
#  'Subgenre_alternative rock',
#  'Subgenre_country',
#  'Subgenre_country pop',
#  'Subgenre_dance',
#  'Subgenre_dance electronic',
#  'Subgenre_dance pop',
#  'Subgenre_electronic',
#  'Subgenre_electronic dance',
#  'Subgenre_electronic pop',
#  'Subgenre_folk',
#  'Subgenre_folk rock',
#  'Subgenre_hip hop',
#  'Subgenre_hip hop 90s',
#  'Subgenre_hip hop rnb',
#  'Subgenre_indie',
#  'Subgenre_indie alternative',
#  'Subgenre_indie folk',
#  'Subgenre_indie pop',
#  'Subgenre_indie rock',
#  'Subgenre_pop',
#  'Subgenre_pop 60s',
#  'Subgenre_pop 70s',
#  'Subgenre_pop 80s',
#  'Subgenre_pop 90s',
#  'Subgenre_pop dance',
#  'Subgenre_pop rnb',
#  'Subgenre_pop rock',
#  'Subgenre_pop synthpop',
#  'Subgenre_rnb',
#  'Subgenre_rock',
#  'Subgenre_rock 60s',
#  'Subgenre_rock 70s',
#  'Subgenre_rock 80s',
#  'Subgenre_rock 90s',
#  'Subgenre_rock alternative',
#  'Subgenre_soul',
#  'Subgenre_soul 60s',
#  'Subgenre_soul 70s',
#  'Subgenre_soul 80s',
#  'Subgenre_soul disco',
#  'Subgenre_soul rnb']

# %%
df_train_encoded.head()
# Out:
#                                                 Song  \
# 2739  Stretch You Out (feat. A Boogie wit da Hoodie)
# 440                               On Melancholy Hill
# 508                                       WHO CARES?
# 76                                             Solid
# 1947                                   BREAK MY SOUL
#
#                                     Artist  Popularity       BPM     Dance  \
# 2739  Summer Walker,A Boogie Wit da Hoodie        0.50  0.317647  0.623529
# 440                               Gorillaz        0.80  0.417647  0.682353
# 508                      Rex Orange County        0.35  0.217647  0.835294
# 76                       Ashford & Simpson        0.45  0.305882  0.823529
# 1947                               Beyoncé        0.55  0.388235  0.682353
#
#         Energy  Acoustic     Happy  Loud  \
# 2739  0.494737  0.252525  0.231579  0.76
# 440   0.726316  0.000000  0.578947  0.80
# 508   0.242105  0.595960  0.589474  0.80
# 76    0.442105  0.272727  0.978947  0.56
# 1947  0.884211  0.060606  0.863158  0.84
#
#                                            Clean_Lyrics  ...  \
# 2739  get london da track niggas insecure claim enou...  ...
# 440   melancholy hill good side consumerism like muc...  ...
# 508   mmmm mmmm mmmm mmmm first time try free doubt ...  ...
# 76    love sake mistake oh forgave soon learn trust ...  ...
# 1947  bout explode take load bend bust open ya make ...  ...
#
#       Subgenre_rock 70s  Subgenre_rock 80s  Subgenre_rock 90s  \
# 2739                0.0                0.0                0.0
# 440                 0.0                0.0                0.0
# 508                 0.0                0.0                0.0
# 76                  0.0                0.0                0.0
# 1947                0.0                0.0                0.0
#
#       Subgenre_rock alternative  Subgenre_soul  Subgenre_soul 60s  \
# 2739                        0.0            0.0                0.0
# 440                         0.0            0.0                0.0
# 508                         0.0            0.0                0.0
# 76                          0.0            0.0                0.0
# 1947                        0.0            0.0                0.0
#
#       Subgenre_soul 70s  Subgenre_soul 80s  Subgenre_soul disco  \
# 2739                0.0                0.0                  0.0
# 440                 0.0                0.0                  0.0
# 508                 0.0                0.0                  0.0
# 76                  0.0                1.0                  0.0
# 1947                0.0                0.0                  0.0
#
#       Subgenre_soul rnb
# 2739                1.0
# 440                 0.0
# 508                 0.0
# 76                  0.0
# 1947                0.0
#
# [5 rows x 67 columns]

# %% [markdown]
# Tokenize the Lyrics

# %%
def simple_tokenize(text):
  return text.split()

# %%
# Apply to all three DataFrames
for df in [df_train_encoded, df_val_encoded, df_test_encoded]:
    df['Tokens'] = df['Clean_Lyrics'].apply(simple_tokenize)

# %%
df_train_encoded.head()
# Out:
#                                                 Song  \
# 2739  Stretch You Out (feat. A Boogie wit da Hoodie)
# 440                               On Melancholy Hill
# 508                                       WHO CARES?
# 76                                             Solid
# 1947                                   BREAK MY SOUL
#
#                                     Artist  Popularity       BPM     Dance  \
# 2739  Summer Walker,A Boogie Wit da Hoodie        0.50  0.317647  0.623529
# 440                               Gorillaz        0.80  0.417647  0.682353
# 508                      Rex Orange County        0.35  0.217647  0.835294
# 76                       Ashford & Simpson        0.45  0.305882  0.823529
# 1947                               Beyoncé        0.55  0.388235  0.682353
#
#         Energy  Acoustic     Happy  Loud  \
# 2739  0.494737  0.252525  0.231579  0.76
# 440   0.726316  0.000000  0.578947  0.80
# 508   0.242105  0.595960  0.589474  0.80
# 76    0.442105  0.272727  0.978947  0.56
# 1947  0.884211  0.060606  0.863158  0.84
#
#                                            Clean_Lyrics  ...  \
# 2739  get london da track niggas insecure claim enou...  ...
# 440   melancholy hill good side consumerism like muc...  ...
# 508   mmmm mmmm mmmm mmmm first time try free doubt ...  ...
# 76    love sake mistake oh forgave soon learn trust ...  ...
# 1947  bout explode take load bend bust open ya make ...  ...
#
#       Subgenre_rock 80s  Subgenre_rock 90s  Subgenre_rock alternative  \
# 2739                0.0                0.0                        0.0
# 440                 0.0                0.0                        0.0
# 508                 0.0                0.0                        0.0
# 76                  0.0                0.0                        0.0
# 1947                0.0                0.0                        0.0
#
#       Subgenre_soul  Subgenre_soul 60s  Subgenre_soul 70s  Subgenre_soul 80s  \
# 2739            0.0                0.0                0.0                0.0
# 440             0.0                0.0                0.0                0.0
# 508             0.0                0.0                0.0                0.0
# 76              0.0                0.0                0.0                1.0
# 1947            0.0                0.0                0.0                0.0
#
#       Subgenre_soul disco  Subgenre_soul rnb  \
# 2739                  0.0                1.0
# 440                   0.0                0.0
# 508                   0.0                0.0
# 76                    0.0                0.0
# 1947                  0.0                0.0
#
#                                                  Tokens
# 2739  [get, london, da, track, niggas, insecure, cla...
# 440   [melancholy, hill, good, side, consumerism, li...
# 508   [mmmm, mmmm, mmmm, mmmm, first, time, try, fre...
# 76    [love, sake, mistake, oh, forgave, soon, learn...
# 1947  [bout, explode, take, load, bend, bust, open, ...
#
# [5 rows x 68 columns]

# %%
print(df_train_encoded.columns)
# Out:
# Index(['Song', 'Artist', 'Popularity', 'BPM', 'Dance', 'Energy', 'Acoustic',
#        'Happy', 'Loud', 'Clean_Lyrics', 'Power', 'camelot_sin', 'camelot_cos',
#        'Genre_alternative', 'Genre_country', 'Genre_dance', 'Genre_electronic',
#        'Genre_folk', 'Genre_hip hop', 'Genre_indie', 'Genre_pop', 'Genre_rnb',
#        'Genre_rock', 'Genre_soul', 'Subgenre_alternative',
#        'Subgenre_alternative rnb', 'Subgenre_alternative rock',
#        'Subgenre_country', 'Subgenre_country pop', 'Subgenre_dance',
#        'Subgenre_dance electronic', 'Subgenre_dance pop',
#        'Subgenre_electronic', 'Subgenre_electronic dance',
#        'Subgenre_electronic pop', 'Subgenre_folk', 'Subgenre_folk rock',
#        'Subgenre_hip hop', 'Subgenre_hip hop 90s', 'Subgenre_hip hop rnb',
#        'Subgenre_indie', 'Subgenre_indie alternative', 'Subgenre_indie folk',
#        'Subgenre_indie pop', 'Subgenre_indie rock', 'Subgenre_pop',
#        'Subgenre_pop 60s', 'Subgenre_pop 70s', 'Subgenre_pop 80s',
#        'Subgenre_pop 90s', 'Subgenre_pop dance', 'Subgenre_pop rnb',
#        'Subgenre_pop rock', 'Subgenre_pop synthpop', 'Subgenre_rnb',
#        'Subgenre_rock', 'Subgenre_rock 60s', 'Subgenre_rock 70s',
#        'Subgenre_rock 80s', 'Subgenre_rock 90s', 'Subgenre_rock alternative',
#        'Subgenre_soul', 'Subgenre_soul 60s', 'Subgenre_soul 70s',
#        'Subgenre_soul 80s', 'Subgenre_soul disco', 'Subgenre_soul rnb',
#        'Tokens'],
#       dtype='object')

# %%
df_train_encoded[['camelot_sin', 'camelot_cos']].head()
# Out:
#       camelot_sin  camelot_cos
# 2739     0.258819    -0.965926
# 440     -0.707107     0.707107
# 508     -0.707107    -0.707107
# 76      -0.965926     0.258819
# 1947     0.258819    -0.965926

# %%
num_songs = len(df_train_encoded)

print(num_songs)
# Out:
# 2114

# %%
#Change path to your own when running so no errors occur - the file can be found in the data folder for now
glove_path = '/Users/langleyburke/Downloads/crawl-300d-2M-subword/crawl-300d-2M-subword.vec'

fasttext_model = KeyedVectors.load_word2vec_format(glove_path, binary=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 4
#       1 #Change path to your own when running so no errors occur - the file can be found in the data folder for now
#       2 glove_path = '/Users/langleyburke/Downloads/crawl-300d-2M-subword/crawl-300d-2M-subword.vec'
# ----> 4 fasttext_model = KeyedVectors.load_word2vec_format(glove_path, binary=False)
#
# NameError: name 'KeyedVectors' is not defined

# %%
fasttext_model['love']

# %%
def get_fasttext_embedding(tokens, model, dim=300):
    vectors = [model[word] for word in tokens if word in model]
    if not vectors:
        return np.zeros(dim)
    return np.mean(vectors, axis=0)

# %%
#Creating new column 'Embeddings' for the final lyric conversions

for df in [df_train_encoded, df_val_encoded, df_test_encoded]:
    df['Embeddings'] = df['Tokens'].apply(lambda tokens: get_fasttext_embedding(tokens, fasttext_model))

# %%
df_train_encoded.head()
